# %%
import pandas as pd
import numpy as np
import tensorflow as tf
# Out:
# /Users/sreevardhan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
tf.__version__
# Out:
# '2.16.1'

# %%
df=pd.read_csv("Churn_Modelling.csv")
X=df.iloc[:,3:-1].values
y=df.iloc[:,-1].values

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
print(X)
print(y)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]
# [1 0 1 ... 1 1 0]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X[:,2]=le.fit_transform(X[:,2])

# %%
X
# Out:
# array([[619, 'France', 0, ..., 1, 1, 101348.88],
#        [608, 'Spain', 0, ..., 0, 1, 112542.58],
#        [502, 'France', 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 0, ..., 0, 1, 42085.58],
#        [772, 'Germany', 1, ..., 1, 0, 92888.52],
#        [792, 'France', 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[1])],remainder='passthrough')
X=np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# Initilizing ANN

# %%
ann=tf.keras.models.Sequential()

# %% [markdown]
# Adding input layer and first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# Adding Second Hidden Layer

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# Output Layer

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# Traning The Data

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
ann.fit(X_train,y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 2s 4ms/step - loss: 0.6460 - accuracy: 0.6774
# Epoch 2/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.5110 - accuracy: 0.7959
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4653 - accuracy: 0.7976
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4371 - accuracy: 0.8051
# Epoch 5/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4191 - accuracy: 0.8152
# Epoch 6/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8250
# Epoch 7/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3902 - accuracy: 0.8332
# Epoch 8/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3791 - accuracy: 0.8382
# Epoch 9/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3717 - accuracy: 0.8431
# Epoch 10/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3667 - accuracy: 0.8468
# Epoch 11/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8495
# Epoch 12/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8499
# Epoch 13/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8526
# Epoch 14/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3551 - accuracy: 0.8535
# Epoch 15/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3531 - accuracy: 0.8536
# Epoch 16/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8561
# Epoch 17/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3505 - accuracy: 0.8580
# Epoch 18/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8579
# Epoch 19/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8586
# Epoch 20/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8583
# Epoch 21/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.8601
# Epoch 22/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8585
# Epoch 23/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8606
# Epoch 24/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3428 - accuracy: 0.8626
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3424 - accuracy: 0.8611
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3423 - accuracy: 0.8619
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3415 - accuracy: 0.8634
# Epoch 28/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8629
# Epoch 29/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8621
# Epoch 30/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3406 - accuracy: 0.8611
# Epoch 31/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3405 - accuracy: 0.8621
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3399 - accuracy: 0.8620
# Epoch 33/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8618
# Epoch 34/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8637
# Epoch 35/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8631
# Epoch 36/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3386 - accuracy: 0.8618
# Epoch 37/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8626
# Epoch 38/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3373 - accuracy: 0.8641
# Epoch 39/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8636
# Epoch 40/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8619
# Epoch 41/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8627
# Epoch 42/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3364 - accuracy: 0.8643
# Epoch 43/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3360 - accuracy: 0.8629
# Epoch 44/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8634
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8618
# Epoch 46/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3357 - accuracy: 0.8637
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3353 - accuracy: 0.8629
# Epoch 48/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3357 - accuracy: 0.8637
# Epoch 49/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3353 - accuracy: 0.8629
# Epoch 50/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8618
# Epoch 51/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3352 - accuracy: 0.8634
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8644
# Epoch 53/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.8609
# Epoch 54/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3347 - accuracy: 0.8611
# Epoch 55/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8635
# Epoch 56/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8644
# Epoch 57/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8633
# Epoch 58/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8615
# Epoch 59/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8635
# Epoch 60/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8631
# Epoch 61/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8626
# Epoch 62/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8609
# Epoch 63/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8627
# Epoch 64/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8620
# Epoch 65/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8611
# Epoch 66/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8634
# Epoch 67/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8622
# Epoch 68/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8633
# Epoch 69/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8640
# Epoch 70/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3336 - accuracy: 0.8637
# Epoch 71/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3342 - accuracy: 0.8636
# Epoch 72/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3340 - accuracy: 0.8633
# Epoch 73/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3348 - accuracy: 0.8635
# Epoch 74/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3337 - accuracy: 0.8637
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8611
# Epoch 76/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3345 - accuracy: 0.8629
# Epoch 77/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8621
# Epoch 78/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8636
# Epoch 79/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8609
# Epoch 80/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8624
# Epoch 81/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8645
# Epoch 82/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8620
# Epoch 83/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3337 - accuracy: 0.8622
# Epoch 84/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3337 - accuracy: 0.8641
# Epoch 85/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8627
# Epoch 86/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3336 - accuracy: 0.8641
# Epoch 87/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8627
# Epoch 88/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3337 - accuracy: 0.8639
# Epoch 89/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8636
# Epoch 90/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8646
# Epoch 91/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8627
# Epoch 92/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8630
# Epoch 93/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3336 - accuracy: 0.8620
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3338 - accuracy: 0.8614
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3338 - accuracy: 0.8622
# Epoch 96/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3335 - accuracy: 0.8639
# Epoch 97/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8631
# Epoch 98/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8644
# Epoch 99/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8650
# Epoch 100/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8630

# %%
ann.predict(sc.transform([[1,0,0,600,1,40,3,60000,2,1,1,50000]]))>0.5
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[False]])

# %%
y_pred=ann.predict(X_test)
y_pred = (y_pred >0.5)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[1512   83]
#  [ 198  207]]
# 0.8595
