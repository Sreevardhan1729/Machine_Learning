# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Position_Salaries.csv")
X=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=10,random_state=0)
rfr.fit(X,y) #type: ignore
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
rfr.predict([[6.5]])
# Out:
# array([167000.])

# %%
X_grid=np.arange(min(X),max(X),0.01)
X_grid=X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color="red") #type: ignore
plt.plot(X_grid,rfr.predict(X_grid),color="blue")
plt.title("Random Forest Regressor")
plt.xlabel("Level")
plt.ylabel("Salery")
plt.show()
# Out:
# /var/folders/rx/vr79v8_55bq2g9w9p6n45mfr0000gn/T/ipykernel_41138/3733113294.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid=np.arange(min(X),max(X),0.01)
